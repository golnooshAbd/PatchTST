# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import trapz

# %%
model_name = 'MyTransformer'
sensor = 'STEP_DВbitcanalEST__A107_A_2FAB10_CF001_71-data-2024-12-0612_16_09' #'Hydrique_hydrique-Vuachere_Vallon_hauteur' #'Hydrique_31_002_hauteur'
path_list = [f'/home/abgo/SimpleDL/PatchTST/PatchTST_supervised/test_results/test_all_DTW_LausanneCity_v1_2_96_96_{model_name}_custom_ftMS_OT{sensor}_sl96_ll48_pl96_dm32_nh2_el3_dl1_df128_fc1_ebtimeF_dtTrue_Exp_0_ind0_rnd2021/accuracy_error_plot.npy', f'/home/abgo/SimpleDL/PatchTST/PatchTST_supervised/test_results/test_all_DTW_LausanneCity_v1_3_1_96_96_{model_name}_custom_ftMS_OT{sensor}_sl96_ll48_pl96_dm32_nh2_el3_dl1_df128_fc1_ebtimeF_dtTrue_Exp_0_ind0_rnd2021/accuracy_error_plot.npy',f'/home/abgo/SimpleDL/PatchTST/PatchTST_supervised/test_results/test_all_DTW_LausanneCity_v1_3_3_96_96_{model_name}_custom_ftMS_OT{sensor}_sl96_ll48_pl96_dm32_nh2_el3_dl1_df128_fc1_ebtimeF_dtTrue_Exp_0_ind0_rnd2021/accuracy_error_plot.npy']
name_list = ['LausanneCity V1.2', 'LausanneCity V1.3.1', 'LausanneCity V1.3.3']

# %%
model_name = 'PatchTST'
path_list = [f'/home/abgo/SimpleDL/PatchTST/PatchTST_supervised/test_results/test_all_DTW_LausanneCity_v1_2_96_96_{model_name}_custom_ftMS_OTHydrique_31_002_hauteur_sl96_ll48_pl96_dm32_nh2_el3_dl1_df128_fc1_ebtimeF_dtTrue_Exp_0_ind0_rnd2021/accuracy_error_plot.npy', f'/home/abgo/SimpleDL/PatchTST/PatchTST_supervised/test_results/test_all_DTW_LausanneCity_v1_3_1_96_96_{model_name}_custom_ftMS_OTHydrique_31_002_hauteur_sl96_ll48_pl96_dm32_nh2_el3_dl1_df128_fc1_ebtimeF_dtTrue_Exp_0_ind0_rnd2021/accuracy_error_plot.npy',f'/home/abgo/SimpleDL/PatchTST/PatchTST_supervised/test_results/test_all_DTW_LausanneCity_v1_3_3_96_96_{model_name}_custom_ftMS_OTHydrique_31_002_hauteur_sl96_ll48_pl96_dm32_nh2_el3_dl1_df128_fc1_ebtimeF_dtTrue_Exp_0_ind0_rnd2021/accuracy_error_plot.npy']
name_list = ['LausanneCity V1.2', 'LausanneCity V1.3.1', 'LausanneCity V1.3.3']

# %%
#read npy files
acc_list = []
for path in path_list:
    acc_list.append(np.load(path))

# %%
# Area Under Curve (AUC) Calculation
auc_n_l = [] # AUC normalized list
for i, acc in enumerate(acc_list):
    mse_threshold = acc[0]
    acc_i = acc[1]
    auc = trapz(acc_i, mse_threshold)
    auc_normalized = auc / (mse_threshold[-1] - mse_threshold[0])
    auc_n_l.append(auc_normalized)

# %%
plt.figure()
plt.title(model_name)
for i, (acc, name) in enumerate(zip(acc_list, name_list)):
    plt.plot(acc[0], acc[1], label=f'{name}: AUC {auc_n_l[i]:.4f}')
plt.legend()
plt.ylabel('Accuracy')
plt.xlabel('Error Threshold')
# plt.savefig(f'AUC_{model_name}_LausanneCity.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure()
plt.title(model_name)
for i, (acc, name) in enumerate(zip(acc_list, name_list)):
    plt.plot(acc[0], acc[1], label=f'{name}: AUC {auc_n_l[i]:.4f}')
plt.legend()
plt.ylabel('Accuracy')
plt.xlabel('Error Threshold')
# plt.savefig(f'AUC_{model_name}_LausanneCity.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Plot AUC for all sensors, MyTransformer model

# %%
# plot sensors separately 
model_name = 'MyTransformer'
sensors = ['Hydrique_31_002_hauteur', 'Hydrique_hydrique-Vuachere_Vallon_hauteur', 'STEP_DВbitcanalEST__A107_A_2FAB10_CF001_71-data-2024-12-0612_16_09', 'STEP_DВbitcanalOUEST__A107_A_2FAB10_CF001_71-data-2024-12-0612_16_09' ]
sens_n = ['Hydrique 31_002_hauteur', 'Hydrique  Vuachere_Vallon_hauteur', 'STEP DВbitcanalEST', 'STEP DВbitcanalOUEST']
for s, sens in enumerate(sensors):
    # File paths
    path_list = [f'/home/abgo/SimpleDL/PatchTST/PatchTST_supervised/test_results/test_all_DTW_LausanneCity_v1_2_96_96_{model_name}_custom_ftMS_OT{sens}_sl96_ll48_pl96_dm32_nh2_el3_dl1_df128_fc1_ebtimeF_dtTrue_Exp_0_ind0_rnd2021/accuracy_error_plot.npy', f'/home/abgo/SimpleDL/PatchTST/PatchTST_supervised/test_results/test_all_DTW_LausanneCity_v1_3_1_96_96_{model_name}_custom_ftMS_OT{sens}_sl96_ll48_pl96_dm32_nh2_el3_dl1_df128_fc1_ebtimeF_dtTrue_Exp_0_ind0_rnd2021/accuracy_error_plot.npy',f'/home/abgo/SimpleDL/PatchTST/PatchTST_supervised/test_results/test_all_DTW_LausanneCity_v1_3_3_96_96_{model_name}_custom_ftMS_OT{sens}_sl96_ll48_pl96_dm32_nh2_el3_dl1_df128_fc1_ebtimeF_dtTrue_Exp_0_ind0_rnd2021/accuracy_error_plot.npy']
    name_list = ['LausanneCity V1.2', 'LausanneCity V1.3.1', 'LausanneCity V1.3.3']
    #read npy files
    acc_list = []
    for path in path_list:
        acc_list.append(np.load(path))
    # Area Under Curve (AUC) Calculation
    auc_n_l = [] # AUC normalized list
    for i, acc in enumerate(acc_list):
        mse_threshold = acc[0]
        acc_i = acc[1]
        auc = trapz(acc_i, mse_threshold)
        auc_normalized = auc / (mse_threshold[-1] - mse_threshold[0])
        auc_n_l.append(auc_normalized)
    # Plotting
    plt.figure()
    plt.title(f'{model_name}: {sens_n[s]}')
    for i, (acc, name) in enumerate(zip(acc_list, name_list)):
        plt.plot(acc[0], acc[1], label=f'{name}: AUC {auc_n_l[i]:.4f}')
    plt.legend()
    plt.ylabel('Accuracy')
    plt.xlabel('Error Threshold')
    plt.savefig(f'AUC_{model_name}_{sens_n[s]}_LausanneCity.pdf', dpi=300, bbox_inches='tight')
    plt.show()
    plt.close()

# %%
# Plotting all sensors together
import numpy as np
import matplotlib.pyplot as plt
from numpy import trapz

model_name = 'MyTransformer'
sensors = [
    'Hydrique_31_002_hauteur',
    'Hydrique_hydrique-Vuachere_Vallon_hauteur',
    'STEP_DВbitcanalEST__A107_A_2FAB10_CF001_71-data-2024-12-0612_16_09',
    'STEP_DВbitcanalOUEST__A107_A_2FAB10_CF001_71-data-2024-12-0612_16_09'
]
sens_n = [
    'Hydrique 31_002_hauteur',
    'Hydrique Vuachere_Vallon_hauteur',
    'STEP DВbitcanalEST',
    'STEP DВbitcanalOUEST'
]
name_list = ['LausanneCity V1.2', 'LausanneCity V1.3.1', 'LausanneCity V1.3.3']

fig, axs = plt.subplots(2, 2, figsize=(14, 10))
axs = axs.flatten()

for s, (sensor, sensor_label) in enumerate(zip(sensors, sens_n)):
    # File paths
    path_list = [
        f'/home/abgo/SimpleDL/PatchTST/PatchTST_supervised/test_results/test_all_DTW_LausanneCity_v1_2_96_96_{model_name}_custom_ftMS_OT{sensor}_sl96_ll48_pl96_dm32_nh2_el3_dl1_df128_fc1_ebtimeF_dtTrue_Exp_0_ind0_rnd2021/accuracy_error_plot.npy',
        f'/home/abgo/SimpleDL/PatchTST/PatchTST_supervised/test_results/test_all_DTW_LausanneCity_v1_3_1_96_96_{model_name}_custom_ftMS_OT{sensor}_sl96_ll48_pl96_dm32_nh2_el3_dl1_df128_fc1_ebtimeF_dtTrue_Exp_0_ind0_rnd2021/accuracy_error_plot.npy',
        f'/home/abgo/SimpleDL/PatchTST/PatchTST_supervised/test_results/test_all_DTW_LausanneCity_v1_3_3_96_96_{model_name}_custom_ftMS_OT{sensor}_sl96_ll48_pl96_dm32_nh2_el3_dl1_df128_fc1_ebtimeF_dtTrue_Exp_0_ind0_rnd2021/accuracy_error_plot.npy'
    ]

    acc_list = [np.load(path) for path in path_list]

    # Compute AUCs
    auc_n_l = []
    for acc in acc_list:
        mse_threshold = acc[0]
        acc_i = acc[1]
        auc = trapz(acc_i, mse_threshold)
        auc_normalized = auc / (mse_threshold[-1] - mse_threshold[0])
        auc_n_l.append(auc_normalized)

    # Plot
    ax = axs[s]
    for i, (acc, name) in enumerate(zip(acc_list, name_list)):
        ax.plot(acc[0], acc[1], label=f'{name}\nAUC: {auc_n_l[i]:.4f}')
    ax.set_title(f'{model_name}: {sensor_label}')
    ax.set_xlabel('Error Threshold')
    ax.set_ylabel('Accuracy')
    ax.legend()

plt.tight_layout()
plt.savefig(f'AUC_{model_name}_LausanneCity_ALL.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Plot AUC for all sensors, PatchTST model

# %%
# Plotting all sensors together
import numpy as np
import matplotlib.pyplot as plt
from numpy import trapz

model_name = 'PatchTST'
sensors = [
    'Hydrique_31_002_hauteur',
    'Hydrique_hydrique-Vuachere_Vallon_hauteur',
    'STEP_DВbitcanalEST__A107_A_2FAB10_CF001_71-data-2024-12-0612_16_09',
    'STEP_DВbitcanalOUEST__A107_A_2FAB10_CF001_71-data-2024-12-0612_16_09'
]
sens_n = [
    'Hydrique 31_002_hauteur',
    'Hydrique Vuachere_Vallon_hauteur',
    'STEP DВbitcanalEST',
    'STEP DВbitcanalOUEST'
]
name_list = ['LausanneCity V1.2', 'LausanneCity V1.3.1', 'LausanneCity V1.3.3']

fig, axs = plt.subplots(2, 2, figsize=(14, 10))
axs = axs.flatten()

for s, (sensor, sensor_label) in enumerate(zip(sensors, sens_n)):
    # File paths
    path_list = [
        f'/home/abgo/SimpleDL/PatchTST/PatchTST_supervised/test_results/test_all_DTW_LausanneCity_v1_2_96_96_{model_name}_custom_ftM_OT{sensor}_sl96_ll48_pl96_dm32_nh16_el3_dl1_df128_fc1_ebtimeF_dtTrue_Exp_0_ind0_rnd2021/accuracy_error_plot.npy',
        f'/home/abgo/SimpleDL/PatchTST/PatchTST_supervised/test_results/test_all_DTW_LausanneCity_v1_3_1_96_96_{model_name}_custom_ftM_OT{sensor}_sl96_ll48_pl96_dm32_nh16_el3_dl1_df128_fc1_ebtimeF_dtTrue_Exp_0_ind0_rnd2021/accuracy_error_plot.npy',
        f'/home/abgo/SimpleDL/PatchTST/PatchTST_supervised/test_results/test_all_DTW_LausanneCity_v1_3_3_96_96_{model_name}_custom_ftM_OT{sensor}_sl96_ll48_pl96_dm32_nh16_el3_dl1_df128_fc1_ebtimeF_dtTrue_Exp_0_ind0_rnd2021/accuracy_error_plot.npy'
        ]

    acc_list = [np.load(path) for path in path_list]

    # Compute AUCs
    auc_n_l = []
    for acc in acc_list:
        mse_threshold = acc[0]
        acc_i = acc[1]
        auc = trapz(acc_i, mse_threshold)
        auc_normalized = auc / (mse_threshold[-1] - mse_threshold[0])
        auc_n_l.append(auc_normalized)

    # Plot
    ax = axs[s]
    for i, (acc, name) in enumerate(zip(acc_list, name_list)):
        ax.plot(acc[0], acc[1], label=f'{name}\nAUC: {auc_n_l[i]:.4f}')
    ax.set_title(f'{model_name}: {sensor_label}')
    ax.set_xlabel('Error Threshold')
    ax.set_ylabel('Accuracy')
    ax.legend()

plt.tight_layout()
plt.savefig(f'AUC_{model_name}_LausanneCity_ALL.pdf', dpi=300, bbox_inches='tight')
plt.show()
